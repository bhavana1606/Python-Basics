# %%
(item)
  top = len(S)-1
  print(top)
def Pop(S):
  if isEmpty(S):
    return "Underflow"
  else:
    val=S.pop()
    if len(S)==0:
      top=Nonedef isEmpty(S):
  if len(S)==0:
    return True
  else:
    return False
def Push(S, item):
  S.append
    else:
      top=len(S)-1
    return val
def Peek(S):
  if isEmpty(S):
    return "Underflow"
  else:
    top=len(S)-1
    print(len(S),top)
    return S[top]
def Show(S):
  if isEmpty(S):
    return "No item to show"
  else:
    t=len(S)-1
    print("Top", end=" ")
    while(t>=0):
      print(S[t],"<==",end=" ")
      t-=1
    print()

S=[]
top=None
while(True):
  print("1. Push")
  print("2. Pop")
  print("3. Peek")
  print("4. show")
  print("0.Exit")
  ch=(int(input("Enter the choice:")))
  if ch==1:
    val=(int(input("Enter the value to push:")))
    Push(S,val) #inserting val to stack S
  elif ch==2:
    val=Pop(S)
    if val=="Underflow":
      print("Stack is Empty")
    else:
      print("Deleted item is ",val)
  elif ch==3:
    val=Peek(S)
    if val=="Underflow":
      print("Stack is Empty")
    else:
      print("Top item is ",val)
  elif ch==4:
    Show(S)
  elif ch==0:
    print("Bye")
    break
# Out:
# 1. Push
# 2. Pop
# 3. Peek
# 4. show
# 0.Exit
# Enter the choice:1
# Enter the value to push:23
# 1. Push
# 2. Pop
# 3. Peek
# 4. show
# 0.Exit
# Enter the choice:1
# Enter the value to push:35
# 1. Push
# 2. Pop
# 3. Peek
# 4. show
# 0.Exit
# Enter the choice:4
# Top 35 <== 23 <==
# 1. Push
# 2. Pop
# 3. Peek
# 4. show
# 0.Exit
# Enter the choice:3
# Top item is  35
# 1. Push
# 2. Pop
# 3. Peek
# 4. show
# 0.Exit
# Enter the choice:2
# Deleted item is  35
# 1. Push
# 2. Pop
# 3. Peek
# 4. show
# 0.Exit
# Enter the choice:4
# Top 23 <==
# 1. Push
# 2. Pop
# 3. Peek
# 4. show
# 0.Exit
# Enter the choice:2
# Deleted item is  23
# 1. Push
# 2. Pop
# 3. Peek
# 4. show
# 0.Exit
# Enter the choice:4
# 1. Push
# 2. Pop
# 3. Peek
# 4. show
# 0.Exit
# Enter the choice:2
# Stack is Empty
# 1. Push
# 2. Pop
# 3. Peek
# 4. show
# 0.Exit
# Enter the choice:0
# Bye

# %%
def isEmpty(Q):
  if len(Q)==0:
    return True
  else:
    return False
def Enqueue(Q, item):
  Q.append(item)
  if len(Q)==1:
    front=rear=0
  else:
    rear=len(Q)-1
def Dequeue(Q):
  if isEmpty(Q):
    return "Underflow"
  else:
    val=Q.pop(0)
  if len(Q)==0:
    front=rear=None
  return val
def Peek(Q):
  if isEmpty(Q):
    return "Underflow"
  else:
    front=0
    return Q[front]
def Show(Q):
  if isEmpty(Q):
    return "No item to show"
  else:
    t=len(Q)-1
    print("Front", end=" ")
    front=0
    i=front
    rear=len(Q)-1
    while(i<=rear):
      print(Q[i],"<==",end=" ")
      i+=1
    print()

Q=[]
front=rear=None
while(True):
  print("1. Enqueue")
  print("2. Dequeue")
  print("3. Peek")
  print("4. show")
  print("0.Exit")
  ch=(int(input("Enter the choice:")))
  if ch==1:
    val=(int(input("Enter the value to insert:")))
    Enqueue(Q,val) #inserting val 
  elif ch==2:
    val=Dequeue(Q)
    if val=="Underflow":
      print("Queue is Empty")
    else:
      print("Deleted item is ",val)
  elif ch==3:
    val=Peek(Q)
    if val=="Underflow":
      print("Queue is Empty")
    else:
      print("Front item is ",val)
  elif ch==4:
    Show(Q)
  elif ch==0:
    print("Bye")
    break
# Out:
# 1. Enqueue
# 2. Dequeue
# 3. Peek
# 4. show
# 0.Exit
# Enter the choice:1
# Enter the value to insert:25
# 1. Enqueue
# 2. Dequeue
# 3. Peek
# 4. show
# 0.Exit
# Enter the choice:1
# Enter the value to insert:35
# 1. Enqueue
# 2. Dequeue
# 3. Peek
# 4. show
# 0.Exit
# Enter the choice:1
# Enter the value to insert:65
# 1. Enqueue
# 2. Dequeue
# 3. Peek
# 4. show
# 0.Exit
# Enter the choice:4
# Front 25 <== 35 <== 65 <==
# 1. Enqueue
# 2. Dequeue
# 3. Peek
# 4. show
# 0.Exit
# Enter the choice:2
# Deleted item is  25
# 1. Enqueue
# 2. Dequeue
# 3. Peek
# 4. show
# 0.Exit
# Enter the choice:3
# Front item is  35
# 1. Enqueue
# 2. Dequeue
# 3. Peek
# 4. show
# 0.Exit
# Enter the choice:4
# Front 35 <== 65 <==
# 1. Enqueue
# 2. Dequeue
# 3. Peek
# 4. show
# 0.Exit
# Enter the choice:0
# Bye
