# %%
try:
  a = eval(input('Enter a number: '))
  print (3/a)
except NameError:
  print('Please enter a number.')
except ZeroDivisionError:
  print("Can't enter 0.")
# Out:
#   File "<ipython-input-13-5360915388b7>", line 4
#     try:
#       ^
# SyntaxError: invalid syntax

# %%
try:
  a = eval(input('Enter a number: '))
  print (x/a)
except:
  print('A problem occurred.')
# Out:
# Enter a number: 7a
# A problem occurred.

# %%
a=3
try:
  c = a/0
except Exception as e:
  print(e)
# Out:
# ggg
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-44f02437ff39> in <module>()
# ----> 1 a=eval(input())
#       2 try:
#       3   c = 3/a
#       4 except Exception as e:
#       5   print(e)
#
# <string> in <module>()
#
# NameError: name 'ggg' is not defined

# %%
try:
  file = open('filename.txt', 'r')
except IOError:
  print('Could not open file')
else:
  s = file.read()
print(s)

# %%
f = open('filename.txt', 'w')
s = 'hi'
try:
  # some code that could potentially fail goes here
finally:
  f.close()
