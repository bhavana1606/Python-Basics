# %% [markdown]
# # Tuple

# %%
my_tuple = (1, 2, 3, "abcdef") #create tuple
print(my_tuple)
for x in my_tuple:
    print(x)
print(my_tuple)
print(my_tuple[0])
print(my_tuple[:])
print(my_tuple[3][4])
# Out:
# (1, 2, 3, 'abcdef')
# 1
# 2
# 3
# abcdef
# (1, 2, 3, 'abcdef')
# 1
# (1, 2, 3, 'abcdef')
# e

# %%
my_tuple = (1, 2, 3)
my_tuple = my_tuple + (4, 5, 6) #add elements
print(my_tuple)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
my_tuple = (1, 2, 3, ['hindi', 'python'])
my_tuple[3][0] = 'english'
my_tuple += (1,2,3)
a="abc"
a+="def"
print(a)
print(my_tuple)
print(my_tuple.count(2))
print(my_tuple.index(2))
# Out:
# abcdef
# (1, 2, 3, ['english', 'python'], 1, 2, 3)
# 2
# 1

# %% [markdown]
# # Set

# %%
my_set = {1, 2, 3, 4, 5, 5, 5} #create set
print(my_set)
my_set = {1, 2, 3}
my_set.add(4) #add element to set
print(my_set)
# Out:
# {1, 2, 3, 4, 5}
# {1, 2, 3, 4}

# %%
my_set = {1, 2, 3, 4}
my_set_2 = {3, 4, 5, 6}
print(my_set.union(my_set_2))
print(my_set.intersection(my_set_2))
print(my_set.difference(my_set_2))
print(my_set.symmetric_difference(my_set_2))
my_set.clear()
print(my_set)
"""The union() function combines the data present in both sets.
The intersection() function finds the data present in both sets only.
The difference() function deletes the data present in both and outputs data present only in the set passed.
The symmetric_difference() does the same as the difference() function but outputs the data which is remaining in both sets."""
# Out:
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {1, 2}
# {1, 2, 5, 6}
# set()

# %% [markdown]
# # Dictionary

# %%
my_dict = {} #empty dictionary
print(my_dict)
my_dict = {1: 'abc', 2: 'def'} #dictionary with elements
print(my_dict)

# %%
my_dict = {'First': 'Python', 'Second': 'Java'}
print(my_dict)
my_dict['Second'] = 'C++' #changing element
print(my_dict)
my_dict['Third'] = 'Ruby' #adding key-value pair
print(my_dict)
# Out:
# {'First': 'Python', 'Second': 'Java'}
# {'First': 'Python', 'Second': 'C++'}
# {'First': 'Python', 'Second': 'C++', 'Third': 'Ruby'}

# %%
my_dict = {'First': 'Python', 'Second': 'Java', 'Third': 'Ruby'}
print(my_dict.keys()) #get keys
print(my_dict.values()) #get values
print(my_dict.items()) #get key-value pairs
print(my_dict.get('First'))
# Out:
# dict_keys(['First', 'Second', 'Third'])
# dict_values(['Python', 'Java', 'Ruby'])
# dict_items([('First', 'Python'), ('Second', 'Java'), ('Third', 'Ruby')])
# Python

# %%
my_dict = {'First': 'Python', 'Second': 'Java'}
print(my_dict['First']) #access elements using keys
print(my_dict.get('Second'))

# %%
my_dict = {'First': 'Python', 'Second': 'Java', 'Third': 'Ruby'}
print(my_dict.keys()) #get keys
print(my_dict.values()) #get values
print(my_dict.items()) #get key-value pairs
print(my_dict.get('First'))

# %% [markdown]
# # Programs

# %%
# concatenate more than two lists

print([9] + [4, 35, 2] + [22, 9, 3])

# %%
'''create a list of 5 integers and concatenate it with an empty list. Print the result.'''
lst1=[]
lst2=[2,5,8,9,10]
lst3=lst1+lst2
print(lst3)
# Out:
# [2, 5, 8, 9, 10]

# %%
# repeatition

'''
Which operator did you use for repeating a string?
a. + 
b. -
c. %
d. *
Show with example
'''
lst=[2,4,32,3,19]
print(lst*4)
# Out:
# [2, 4, 32, 3, 19, 2, 4, 32, 3, 19, 2, 4, 32, 3, 19, 2, 4, 32, 3, 19]

# %%
another_lst = [2, -8.9, 'Pattern', [3, 4, 5], ()] # what's the type off last element in the list?
'''Access each element in the list another_lst and print its type.'''
for item in another_lst:
  print(type(item))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'list'>
# <class 'tuple'>

# %%
#Tuple's elements cannot be changed, but we have an indirect way to do the same

tuple1 = ("apple", "banana", "orange")
list1 = list(tuple1)
list1[1] = "papaya"
tuple1 = tuple(list1)

print(tuple1)
# Out:
# ('apple', 'papaya', 'orange')

# %%
# Another way to create a tuple

course = 'intro to python', 'Amey', 101
student = 'Prasanna', 34, course

print(type(course))
print(type(student))
# Out:
# <class 'tuple'>
# <class 'tuple'>

# %%
tuple1 = 'Akash', 34, 'CSE'
tuple2 = 'Aman', 35, 'ECE'
name, roll_no, disc = tuple1
print(name)
print(roll_no)
print(disc)
# Out:
# Aman
# 35
# ECE

# %%
# we can do the same with strings too..

a, b, c = 'CSE'
print(a)
print(b)
print(c)
# Out:
# C
# S
# E

# %%
#List Comprehension
nums = [-1, 25, 9, -30, 5]

pos = [x for x in nums if x > 0]
print(pos)

sqneg = [x * x  for x in nums if x < 0]
print(sqneg)

abspairs = [(x, abs(x)) for x in nums]
print(abspairs)
# Out:
# [25, 9, 5]
# [1, 900]
# [(-1, 1), (25, 25), (9, 9), (-30, 30), (5, 5)]

# %%
# add a pair (x, y) in a list if for x in list1 its square y is present in list2

new_list = []
for x in [1, 2, 3]:
  for y in [12, 9, 27, 4, 50]:
    if x * x == y:
      new_list.append((x, y))
print(new_list)
# Out:
# [(2, 4), (3, 9)]

# %%
basket = ['apple', 'orange', 'apple', 'pear', 'orange', 'banana'] # note that some values are repeated
fruits = set(basket)
print(fruits)
# Out:
# {'pear', 'banana', 'orange', 'apple'}

# %%
# set of operations

A = set('acads')
print(A)
B = set('institute')
print(B)

# %%
# set difference
A - B
# set union
A | B
# set intersection
A  & B
# symmetric difference
A ^ B

# %%
# create a dictionary

capital = {'India': 'New Delhi', 'INDIA': 'Washington DC', 'France':'Paris', 'Sri Lanka': 'Colombo'}
print(capital)

# %%
# get capital of India
capital['India']

# %%
# get capital of UK
capital['UK']

# %%
# alternative
capital.get('UK', 'Unknown') # if key is not present, set default value

# %%
# update value of the key 'UK'
capital['UK'] = 'London'
print(capital)

# %%
# get all keys
capital.keys()

# %%
# get length of the disctionary
len(capital)

# %%
# check if a key is present in a dictionary
'USA' in capital

# %%
# delete the key:value pair from the dictionary
del capital['USA']

# %%
# iterate over keys and add them to a list
countries = []
for key in capital:
  countries.append(key)
countries

# %%
# build dictionary using exsting sequence of pairs
airports = dict([('Mumbai', 'BOM'), ('Delhi', 'Del'), ('Chennai', 'MAA'), ('Kolkata', 'CCU')])
airports

# %%
# create a dictionary: key as a number and value as its square
squares_dict = {x: x * x for x in range(1, 5)}
squares_dict

# %%
#create list using range
numbers_list = list(range(0, 21, 2)) 
print(numbers_list)

# %%
# zip()

numbers = [1, 2, 3, 4, 5]
squares = [1, 4, 9, 16, 25]


pairs = []

for num, sq in zip(numbers, squares):
  pairs.append((num, sq))

print(pairs)

# %%
'''
Q1. Write a program to perform the following tasks:
- Read a list of integers from a user. (A user may enter one or more values)
- In a single scan of the list, perform the following operations in the given order:
  - If a value is non-numeric, then replace it with its corresponding 'ASCII sum'. If it is a float value, then map it to the closest higher integer number.
    - ASCII sum: the sum of ASCII values of each character in the string.
  - Remove duplicate values from this list. We call it a super list.
- In a single scan of the super list, perform the following operations in the given order:
  - If the number is perfectly divisible by 3, discard it.
  - If the number is greater than 30, add 5 to it. Else, subtrat 5 from it.
  - If the updated number is a prime number, then discard it.
- If the list is empty after performing the above operations, display 'Empty'. Otherwise, display contents of the list.
'''
